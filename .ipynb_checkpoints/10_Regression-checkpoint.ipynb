# %%
import findspark
findspark.init()

# %%
from pyspark.ml.regression import LinearRegression
from pyspark.sql import SparkSession
from pyspark.ml.linalg import Vectors

# %%
# create a sparksession (windows specific)
spark = SparkSession.builder \
    .master("local") \
    .appName("LinearRegression") \
    .config("spark.sql.warehouse.dir", "file:///C:/temp") \
    .getOrCreate()

# %%
inputLines = spark.sparkContext.textFile("../SparkData/regression.txt")

# %%
# take raw data and convert to MLLib friendly format
data = inputLines.map(lambda x: x.split(",")).map(lambda x: \
                         ( float(x[0]), Vectors.dense(float(x[1])) ) )

# %%
data.top(5)
# Out:
# [(2.76, DenseVector([-2.8])),
#  (2.71, DenseVector([-2.9])),
#  (2.67, DenseVector([-2.51])),
#  (2.62, DenseVector([-2.69])),
#  (2.56, DenseVector([-2.6]))]

# %%
# convert RDD to a DataFrame, set appropriate column header names
colNames = ["label", "features"]
df = data.toDF(colNames)

# %%
df.show(5)
# Out:
# +-----+--------+
# |label|features|
# +-----+--------+
# |-1.74|  [1.66]|
# | 1.24| [-1.18]|
# | 0.29|  [-0.4]|
# |-0.13|  [0.09]|
# |-0.39|  [0.38]|
# +-----+--------+
# only showing top 5 rows

# %%
# set up a 50/50 train test split
trainTest = df.randomSplit([0.5, 0.5])
trainingDF = trainTest[0]
testDF = trainTest[1]

# %%
# create a linear regression model
lir = LinearRegression(maxIter=10, regParam=0.3, elasticNetParam=0.8)

# %%
# train model using training data
model = lir.fit(trainingDF)

# %%
# predict values in the test section of data
# cache to ensure persistence
fullPredictions = model.transform(testDF).cache()

# %%
fullPredictions.show(5)
# Out:
# +-----+--------+-------------------+
# |label|features|         prediction|
# +-----+--------+-------------------+
# |-3.54|  [3.44]| -2.449195925445587|
# |-3.23|  [3.26]|-2.3218189659186192|
# |-2.89|  [2.89]|-2.0599885491131866|
# | -2.6|  [2.58]|-1.8406171188167424|
# |-2.54|  [2.49]|-1.7769286390532588|
# +-----+--------+-------------------+
# only showing top 5 rows

# %%
# extract the predictions and "known" correct labels
predictions = fullPredictions.select("prediction").rdd.map(lambda x: x[0])
labels = fullPredictions.select("label").rdd.map(lambda x: x[0])

# %%
# zip them together
predictionAndLabel = predictions.zip(labels).collect()

# %%
for prediction in predictionAndLabel:
    print(prediction)
# Out:
# (-2.449195925445587, -3.54)
# (-2.3218189659186192, -3.23)
# (-2.0599885491131866, -2.89)
# (-1.8406171188167424, -2.6)
# (-1.7769286390532588, -2.54)
# (-1.6707811727807858, -2.43)
# (-1.7344696525442695, -2.36)
# (-1.564633706508313, -2.27)
# (-1.607092693017302, -2.26)
# (-1.4938687289933308, -2.14)
# (-1.3594152717148653, -2.12)
# (-1.3947977604723563, -2.06)
# (-1.4443332447328436, -2.0)
# (-1.500945226744829, -1.98)
# (-1.387721262720858, -1.94)
# (-1.3947977604723563, -1.91)
# (-1.4160272537268508, -1.87)
# (-1.203732321181905, -1.83)
# (-1.3169562852058763, -1.8)
# (-1.239114809939396, -1.79)
# (-1.281573796448385, -1.7)
# (-1.1258908459154249, -1.68)
# (-1.2249618144363996, -1.68)
# (-1.2532678054423925, -1.68)
# (-1.1541968369214177, -1.66)
# (-1.2249618144363996, -1.66)
# (-1.3169562852058763, -1.64)
# (-1.1329673436669232, -1.63)
# (-1.2320383121878977, -1.61)
# (-1.1046613526609304, -1.6)
# (-1.0692788639034394, -1.54)
# (-1.1541968369214177, -1.54)
# (-0.021957196681706852, -0.09)
# (-0.0856456764451906, -0.09)
# (-0.12810466295417974, -0.09)
# (-0.11395166745118337, -0.08)
# (-0.029033694433205047, -0.07)
# (-0.05733968543919781, -0.07)
# (0.027578287578780496, -0.05)
# (-0.0007277034272122739, -0.05)
# (-0.021957196681706852, -0.05)
# (-0.029033694433205047, -0.05)
# (-0.0785691786936924, -0.05)
# (-0.14225765845717614, -0.05)
# (-0.17764014721466712, -0.04)
# (-0.10687516969968518, -0.03)
# (0.07003727408776965, -0.02)
# (0.06296077633627147, -0.02)
# (0.041731283081776885, -0.02)
# (0.013425292075784112, -0.02)
# (0.013425292075784112, -0.02)
# (-0.007804201178710467, -0.02)
# (-0.11395166745118337, -0.02)
# (-0.14933415620867432, -0.01)
# (-0.16348715171167072, -0.01)
# (0.05588427858477328, -0.0)
# (-0.03611019218470324, -0.0)
# (0.0346547853302787, 0.0)
# (0.027578287578780496, 0.0)
# (-0.11395166745118337, 0.0)
# (0.027578287578780496, 0.01)
# (0.02050178982728231, 0.02)
# (-0.01488069893020866, 0.02)
# (-0.021957196681706852, 0.02)
# (-0.021957196681706852, 0.04)
# (0.09834326509376243, 0.05)
# (0.08419026959076606, 0.06)
# (0.027578287578780496, 0.08)
# (0.09834326509376243, 0.09)
# (0.08419026959076606, 0.09)
# (0.013425292075784112, 0.09)
# (-0.021957196681706852, 0.09)
# (0.07003727408776965, 0.1)
# (-0.029033694433205047, 0.1)
# (0.09834326509376243, 0.11)
# (0.08419026959076606, 0.11)
# (0.04880778083327508, 0.11)
# (0.0346547853302787, 0.11)
# (0.013425292075784112, 0.11)
# (-0.007804201178710467, 0.11)
# (0.20449073136623533, 0.14)
# (0.18326123811174078, 0.14)
# (0.08419026959076606, 0.14)
# (0.041731283081776885, 0.14)
# (0.2327967223722281, 0.15)
# (0.12664925609975522, 0.15)
# (0.1337257538512534, 0.16)
# (0.12664925609975522, 0.16)
# (0.2540262156267227, 0.17)
# (0.05588427858477328, 0.17)
# (-0.0007277034272122739, 0.17)
# (0.11249626059675882, 0.18)
# (0.09126676734226423, 0.18)
# (0.04880778083327508, 0.18)
# (0.12664925609975522, 0.19)
# (0.04880778083327508, 0.19)
# (0.16910824260874438, 0.2)
# (0.16203174485724617, 0.21)
# (0.1478787493542498, 0.21)
# (0.2540262156267227, 0.22)
# (0.2115672291177335, 0.22)
# (0.19741423361473712, 0.23)
# (0.15495524710574796, 0.23)
# (0.17618474036024256, 0.24)
# (0.15495524710574796, 0.25)
# (0.15495524710574796, 0.25)
# (0.11249626059675882, 0.25)
# (0.18326123811174078, 0.26)
# (0.2327967223722281, 0.28)
# (0.2681792111297191, 0.29)
# (0.16203174485724617, 0.29)
# (0.1478787493542498, 0.29)
# (0.1337257538512534, 0.29)
# (0.2398732201237263, 0.3)
# (0.19033773586323893, 0.3)
# (0.16910824260874438, 0.3)
# (0.20449073136623533, 0.31)
# (0.16203174485724617, 0.33)
# (0.10541976284526064, 0.33)
# (0.17618474036024256, 0.34)
# (0.12664925609975522, 0.34)
# (0.2611027133782209, 0.38)
# (0.21864372686923172, 0.38)
# (0.31063819763870826, 0.39)
# (0.28233220663271547, 0.39)
# (0.19033773586323893, 0.39)
# (0.3460206863961992, 0.4)
# (0.31063819763870826, 0.4)
# (0.2611027133782209, 0.4)
# (0.2398732201237263, 0.4)
# (0.374326677402192, 0.41)
# (0.27525570888121725, 0.41)
# (0.19033773586323893, 0.42)
# (0.3177146953902064, 0.43)
# (0.29648520213571183, 0.44)
# (0.2540262156267227, 0.44)
# (0.24694971787522446, 0.44)
# (0.3530971841476974, 0.45)
# (0.28233220663271547, 0.45)
# (0.27525570888121725, 0.45)
# (0.2894087043842136, 0.46)
# (0.22572022462072994, 0.47)
# (0.3955561706566865, 0.48)
# (0.30356169988721005, 0.49)
# (0.29648520213571183, 0.49)
# (0.4238621616626793, 0.5)
# (0.4238621616626793, 0.51)
# (0.3460206863961992, 0.51)
# (0.20449073136623533, 0.51)
# (0.3814031751536902, 0.53)
# (0.29648520213571183, 0.53)
# (0.4521681526686721, 0.55)
# (0.2611027133782209, 0.56)
# (0.4521681526686721, 0.58)
# (0.4167856639111811, 0.58)
# (0.3884796729051883, 0.58)
# (0.4097091661596829, 0.59)
# (0.4450916549171739, 0.63)
# (0.3814031751536902, 0.63)
# (0.48047414367466484, 0.64)
# (0.4238621616626793, 0.64)
# (0.4380151571656757, 0.65)
# (0.4097091661596829, 0.65)
# (0.3672501796506938, 0.65)
# (0.30356169988721005, 0.65)
# (0.4380151571656757, 0.67)
# (0.5795451121956395, 0.68)
# (0.5087801346806575, 0.68)
# (0.4309386594141775, 0.68)
# (0.4167856639111811, 0.68)
# (0.6007746054501341, 0.69)
# (0.5017036369291593, 0.69)
# (0.5017036369291593, 0.69)
# (0.4309386594141775, 0.69)
# (0.4238621616626793, 0.69)
# (0.6149276009531305, 0.7)
# (0.5653921166926431, 0.7)
# (0.374326677402192, 0.7)
# (0.558315618941145, 0.72)
# (0.5370861256866504, 0.72)
# (0.5512391211896468, 0.73)
# (0.48047414367466484, 0.73)
# (0.5370861256866504, 0.74)
# (0.4521681526686721, 0.74)
# (0.4380151571656757, 0.74)
# (0.4097091661596829, 0.74)
# (0.3955561706566865, 0.74)
# (0.5866216099471376, 0.75)
# (0.4097091661596829, 0.75)
# (0.5512391211896468, 0.76)
# (0.5300096279351522, 0.76)
# (0.46632114817166853, 0.77)
# (0.558315618941145, 0.78)
# (0.5512391211896468, 0.78)
# (0.49462713917766127, 0.79)
# (0.6220040987046287, 0.8)
# (0.5724686144441413, 0.82)
# (0.5017036369291593, 0.82)
# (0.5795451121956395, 0.84)
# (0.5653921166926431, 0.84)
# (0.5017036369291593, 0.84)
# (0.7493810582315962, 0.86)
# (0.6644630852136177, 0.86)
# (0.706922071722607, 0.87)
# (0.6644630852136177, 0.9)
# (0.6220040987046287, 0.9)
# (0.5724686144441413, 0.9)
# (0.6573865874621196, 0.91)
# (0.6644630852136177, 0.93)
# (0.6644630852136177, 0.93)
# (0.6432335919591233, 0.93)
# (0.5866216099471376, 0.93)
# (0.5441626234381486, 0.93)
# (0.6078511032016323, 0.94)
# (0.7210750672256034, 0.95)
# (0.6149276009531305, 0.95)
# (0.5936981076986358, 0.95)
# (0.5441626234381486, 0.95)
# (0.7493810582315962, 0.96)
# (0.5795451121956395, 0.96)
# (0.6361570942076251, 0.97)
# (0.7352280627285998, 0.98)
# (0.6290805964561269, 0.98)
# (0.6927690762196106, 0.99)
# (0.6503100897106214, 0.99)
# (0.6078511032016323, 0.99)
# (0.7493810582315962, 1.0)
# (0.671539582965116, 1.0)
# (0.671539582965116, 1.01)
# (0.6503100897106214, 1.01)
# (0.6220040987046287, 1.01)
# (0.7281515649771015, 1.02)
# (0.6220040987046287, 1.03)
# (0.7281515649771015, 1.04)
# (0.6149276009531305, 1.04)
# (0.7989165424920834, 1.05)
# (0.7493810582315962, 1.05)
# (0.7706105514860908, 1.06)
# (0.7706105514860908, 1.08)
# (0.7493810582315962, 1.08)
# (0.7281515649771015, 1.09)
# (0.6573865874621196, 1.1)
# (0.8979875110130582, 1.11)
# (0.8342990312495744, 1.11)
# (0.8059930402435816, 1.11)
# (0.7635340537345926, 1.12)
# (0.9333699997705492, 1.13)
# (0.7493810582315962, 1.13)
# (0.8413755290010726, 1.14)
# (0.7352280627285998, 1.14)
# (0.9970584795340328, 1.15)
# (0.9758289862795383, 1.17)
# (0.8413755290010726, 1.19)
# (0.8272225334980762, 1.19)
# (0.777687049237589, 1.19)
# (0.9050640087645564, 1.22)
# (0.8201460357465781, 1.24)
# (0.926293502019051, 1.25)
# (0.9121405065160546, 1.26)
# (0.8342990312495744, 1.27)
# (0.8130695379950799, 1.27)
# (0.7706105514860908, 1.27)
# (0.8838345155100619, 1.28)
# (0.9970584795340328, 1.29)
# (0.89091101326156, 1.31)
# (0.9121405065160546, 1.34)
# (0.9404464975220475, 1.35)
# (0.926293502019051, 1.38)
# (1.0324409682915239, 1.39)
# (0.9616759907765419, 1.39)
# (1.0253644705400258, 1.41)
# (0.8413755290010726, 1.41)
# (0.9121405065160546, 1.42)
# (0.9829054840310365, 1.47)
# (0.8979875110130582, 1.47)
# (1.0395174660430222, 1.48)
# (1.0112114750370294, 1.49)
# (1.0890529503035096, 1.5)
# (1.0607469592975167, 1.52)
# (1.0536704615460186, 1.52)
# (1.103205945806506, 1.53)
# (1.0748999548005131, 1.53)
# (1.2022769143274805, 1.54)
# (1.1173589413095024, 1.54)
# (1.0395174660430222, 1.54)
# (1.1173589413095024, 1.55)
# (1.1315119368124988, 1.56)
# (1.103205945806506, 1.59)
# (1.2588888963394662, 1.62)
# (1.0465939637945203, 1.64)
# (0.9829054840310365, 1.64)
# (1.1668944255699896, 1.66)
# (1.1598179278184915, 1.69)
# (1.1385884345639967, 1.73)
# (1.0607469592975167, 1.74)
# (1.2376594030849717, 1.78)
# (1.251812398587968, 1.8)
# (1.1952004165759824, 1.82)
# (1.2659653940909643, 1.85)
# (1.3084243805999536, 1.86)
# (1.2801183895939607, 1.91)
# (1.365036362611939, 1.96)
# (1.2942713850969572, 2.0)
# (1.5702547974053869, 2.25)
# (1.6268667794173721, 2.27)
# (1.5065663176419029, 2.33)
# (1.775473232198834, 2.48)
# (1.8250087164593216, 2.56)
# (1.8886971962228052, 2.62)
# (1.7613202366958376, 2.67)
# (2.0373036490042673, 2.71)
